# %%
from model import NNet

# %%
model_1 = NNet(model_to_load='uxception_final_dice.h5')
model_2 = NNet(model_to_load='uresxception_final_dice.h5')
model_3 = NNet(model_to_load='uresxceptionsp_final_dice.h5')
models = [model_1, model_2, model_3]

# %%
predictions = []

for model in models:
    predictions.append(model.predict_test_data())

# %%
import numpy as np

mean_ensemble = np.mean(np.array(predictions), axis=0)

# %%
assert model_1.test_data_gen.numbers == model_2.test_data_gen.numbers == model_3.test_data_gen.numbers

# %%
model_1.test_images_predictions = mean_ensemble

# %%
model_1.display_test_predictions()

# %%
mean_sub = model_1.create_submission_file(path='submission_mean_ensemble.csv', treshold=.25)
