# %%
from model import NNet

# %%
net_types = ['uxception', 'uresxception', 'uresxceptionsp']
net_to_train = net_types[2]

net = NNet(net_type=net_to_train)

# %%
net.train(loss='dice', epochs=40, train_on='google_data', batch_size=6)

# %%
net.save_model('uresxceptionsp_only_google_dice_40_epochs.h5')

# %%
net.check_outputs()

# %%
net.evaluate_model()

# %%
net.train(loss='dice', epochs=50, train_on='competition_data', l_rate=.00001, batch_size=6)

# %%
net.save_model('uresxceptionsp_final_dice.h5')

# %%
net.check_outputs()

# %%
net.evaluate_model()

# %%
# %%capture
net.predict_test_data()

# %%
net.display_test_predictions()

# %%
sub_path = 'submission_{}.csv'.format(net_to_train)
sub = net.create_submission_file(path=sub_path)
